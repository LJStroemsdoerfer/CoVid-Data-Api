# %%
# import libs
from covid_data_germany.covid_data_germany import covid_data_germany

# %%
# initiate the class
dataset = covid_data_germany()

# %%
# get the county level data
dataset.get_data(level = "county")

# %%
dataset.data.head(n = 5)
# Out:
#    OBJECTID ADE GF BSG     RS    AGS        SDV_RS           GEN  \
# 0         1   4  4   1  01001  01001  010010000000     Flensburg
# 0         2   4  4   1  01002  01002  010020000000          Kiel
# 0         3   4  4   1  01003  01003  010030000000        Lübeck
# 0         4   4  4   1  01004  01004  010040000000    Neumünster
# 0         5   4  4   1  01051  01051  010510044044  Dithmarschen
#
#                 BEZ IBZ       ...          Shape__Area  Shape__Length  \
# 0  Kreisfreie Stadt  40       ...         4.918293e+07   42752.592015
# 0  Kreisfreie Stadt  40       ...         1.122314e+08  104373.457289
# 0  Kreisfreie Stadt  40       ...         2.116771e+08  146459.457897
# 0  Kreisfreie Stadt  40       ...         7.140224e+07   54863.995416
# 0             Kreis  42       ...         1.425511e+09  250768.570200
#
#   death_rate cases deaths cases_per_100k cases_per_population  \
# 0   0.000000    13      0      14.524491             0.014524
# ...

# %%
# get the state level data
dataset.get_data(level = "state")

# %%
dataset.data.head(n = 5)
# Out:
#    OBJECTID_1 LAN_ew_AGS           LAN_ew_GEN            LAN_ew_BEZ  \
# 0           1         01   Schleswig-Holstein                  Land
# 0           2         02              Hamburg  Freie und Hansestadt
# 0           3         03        Niedersachsen                  Land
# 0           4         04               Bremen      Freie Hansestadt
# 0           5         05  Nordrhein-Westfalen                  Land
#
#    LAN_ew_EWZ  OBJECTID  Fallzahl  Aktualisierung AGS_TXT  \
# 0     2889821        15       347   1584576000000      01
# 0     1830584         6       872   1584576000000      02
# 0     7962775         9      1306   1584576000000      03
# 0      681032         5       165   1584576000000      04
# 0    17912134        10      3545   1584576000000      05
#
#                                GlobalID  faelle_100000_EW   Shape__Area  \
# 0  fc5ba936-c95c-432c-8a33-9eb2f30b660f         12.007664  4.573731e+10
# ...
